# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
tests = [pd.read_csv(f"data/test/{i}.csv") for i in range(81)]
sample_submission = pd.read_csv("data/sample_submission.csv")

# %%
feature_time = ["Year", "Day", "Time"]

# %%
# DHI : Diffuse Horizontal Irrandiance // 수평면 산란일사량, 태양으로부터 직접 경로에 도달하지 않고 대기의 분자와 입자에 의해 산란된 단위 면적 당 방사선의 양
# DNI : Direct Normal Irradiance // 법선면 직달일사량, 태양의 방향에서 수직으로 유지되는 표면의 단위면적 당 태양 복사량
# WS  : Wind Speed         //
# RH  : Reletive humidity // 상대습도
# T   : Temperture

def pipeTimeFeatureSetup(df):
    df.insert(0, "Year", np.floor(df.Day / 365))
    df["Year"] = df.Year.astype(int)
    df["Weekday"] = df["Day"] % 7
    df["Day"] = df["Day"] % 365
    df["Time"] = df.Hour + df.Minute / 60
    return df[['Year', 'Day', 'Time', 'Weekday', 'DHI', 'DNI', 'WS', 'RH', 'T', 'TARGET']]
    
train = pd.read_csv("data/train/train.csv").pipe(pipeTimeFeatureSetup)
train.sample(10)
# Out:
#        Year  Day  Time  Weekday  DHI  DNI   WS      RH   T     TARGET
# 24099     1  137   1.5        5    0    0  1.8  100.00   1   0.000000
# 11344     0  236   8.0        5   94  757  2.0   25.92  27  43.532494
# 50288     2  317  16.0        4   31  558  1.3   36.32  11   9.289817
# 38068     2   63   2.0        2    0    0  3.6   64.09   1   0.000000
# 7359      0  153   7.5        6  110  711  2.0   44.20  17  44.944735
# 19955     1   50  17.5        2   12  213  2.1   67.06   4   1.689188
# 17434     0  363   5.0        6    0    0  1.8   65.22 -11   0.000000
# 3024      0   63   0.0        0    0    0  3.4   60.64 -13   0.000000
# 79        0    1  15.5        1   39  772  0.5   77.79  -1  17.737444
# 6752      0  140  16.0        0  155    6  2.6   54.56  13  14.825846

# %%
plt.figure(figsize=(20, 10))
plt.subplot(211)
yearly = train.groupby("Day").TARGET.mean()
plt.title("Yearly")
plt.plot(yearly, label="Yearly")
plt.plot(yearly.rolling(10).mean(), label="Rolling-10")
plt.legend()
plt.subplot(223)
train.groupby("Time").TARGET.mean().plot(title="Daily")
plt.subplot(224)
train.groupby("Weekday").TARGET.mean().plot(title="Weekday")
plt.show()

# %%
##### 일출/일몰 시간에 대한 고찰
# DHI 와 TARGET의 non-zero 인 위치가 전부 동일하다.
# 따라서 DHI를 기반으로 일출/일몰시간을 유추하는 것이 매우 합당함
# seasonality에 따른 일출/일몰 시간의 변동폭은 30분으로 매우 안정적으로 변화함
# 이 또한 feature 기반으로 변동성을 유추할 수 있으면 보정하여 사용하면 좋을 듯
display((train.DHI.ne(0) == train.TARGET.ne(0)).value_counts())
sun_appear = (
    train.loc[train.TARGET.ne(0), ["Year", "Day", "Time", "TARGET"]]
    .assign(Day=lambda df: df.Year * 365 + df.Day)
    .groupby("Day").Time
)
plt.figure(figsize=(20, 5))
plt.plot(sun_appear.first(), label="SUNRISE")
plt.plot(sun_appear.last(), label="SUNDOWN")
plt.legend()
# Out:
# True    52560
# dtype: int64

# %%
# 일출 일몰 시간을 feature로 삽입
def pipeAddSunriseAndSunset(df):
    sun_appear = (
        df.loc[df.TARGET.ne(0), ["Year", "Day", "Time", "TARGET"]]
        .assign(Day=lambda df_: df_.Year * 365 + df_.Day)
        .groupby("Day").Time
    )
    
    sunrise = sun_appear.first()
    sunrise.name = "Sunrise"
    sunset = sun_appear.last()
    sunset.name = "Sunset"
    df = df.merge(sunrise.reset_index())
    df = df.merge(sunset.reset_index())
    
    return df

train = train.pipe(pipeAddSunriseAndSunset)
train.head()
# Out:
#    Year  Day  Time  Weekday  DHI  DNI   WS     RH   T  TARGET  Sunrise  Sunset
# 0     0    0   0.0        0    0    0  1.5  69.08 -12     0.0      8.0    16.5
# 1     0    0   0.5        0    0    0  1.5  69.06 -12     0.0      8.0    16.5
# 2     0    0   1.0        0    0    0  1.6  71.78 -12     0.0      8.0    16.5
# 3     0    0   1.5        0    0    0  1.6  71.75 -12     0.0      8.0    16.5
# 4     0    0   2.0        0    0    0  1.6  75.20 -12     0.0      8.0    16.5

# %%
train_grouped = pd.DataFrame()
train_grouped["meanDNI"]  = train.groupby(["Year", "Day"]).DNI.mean()
train_grouped["maxDNI"]  = train.groupby(["Year", "Day"]).DNI.max()
train_grouped["meanTARGET"]  = train.groupby(["Year", "Day"]).TARGET.mean()
train_grouped["maxTARGET"]  = train.groupby(["Year", "Day"]).TARGET.max()
train_grouped
# Out:
#              meanDNI  maxDNI  meanTARGET  maxTARGET
# Year Day
# 0    0     78.708333     811    6.520751  33.129393
#      1    295.187500     980   11.025184  48.612666
#      2     24.645833     535    3.165478  17.361857
#      3     66.979167     911    5.810807  38.008390
#      4     22.500000     220    4.817273  25.806465
# ...              ...     ...         ...        ...
# 2    360  306.437500     978   11.261230  48.140787
#      361  206.583333     788    9.349126  41.103112
#      362  171.291667     860    8.875729  43.353431
#      363  309.812500     989   11.114171  46.731107
#      364  181.166667     756    8.710275  39.322261
#
# [1095 rows x 4 columns]

# %%
# https://www.pveducation.org/pvcdrom/properties-of-sunlight/elevation-angle
# https://firstgreenconsulting.wordpress.com/2012/04/26/differentiate-between-the-dni-dhi-and-ghi/
# 한국원자력연구원 위도 경도 37.63358642997611, 127.08376293918955
def pipeAddGlobalHorizontal(train):
    phi = 37.63358642997611 * math.pi / 180
    delta = 23.4 * math.pi / 180
    train = (
        train
        .assign(TC=lambda df: (24 - (df.Sunrise + df.Sunset)) * 30)# TC ; Time Correction
        .assign(LST=lambda df: df.Time + df.TC / 60) # LST ; Local Solar Time
        .assign(HRA=lambda df: math.pi / 12 * (df.LST - 12)) # HRA ; Hour Angle
        .assign(EA=lambda df: np.arcsin(np.sin(delta)*np.sin(phi) + np.cos(delta)*np.cos(phi)*np.cos(df.HRA)))
        .assign(normDNI=lambda df: df.DNI * np.sin(df.EA.map(lambda x: x if x > 0 else 0)))
        .assign(GHI=lambda df: df.normDNI + df.DHI) # Global Horizontal
    )
    return train
    
train = train.pipe(pipeAddGlobalHorizontal)
train.head()
# Out:
#    Year  Day  Time  Weekday  DHI  DNI   WS     RH   T  TARGET  Sunrise  \
# 0     0    0   0.0        0    0    0  1.5  69.08 -12     0.0      8.0
# 1     0    0   0.5        0    0    0  1.5  69.06 -12     0.0      8.0
# 2     0    0   1.0        0    0    0  1.6  71.78 -12     0.0      8.0
# 3     0    0   1.5        0    0    0  1.6  71.75 -12     0.0      8.0
# 4     0    0   2.0        0    0    0  1.6  75.20 -12     0.0      8.0
#
#    Sunset    TC   LST       HRA        EA  normDNI  GHI
# 0    16.5 -15.0 -0.25 -3.207043 -0.503782      0.0  0.0
# 1    16.5 -15.0  0.25 -3.076143 -0.503782      0.0  0.0
# 2    16.5 -15.0  0.75 -2.945243 -0.489666      0.0  0.0
# 3    16.5 -15.0  1.25 -2.814343 -0.461985      0.0  0.0
# 4    16.5 -15.0  1.75 -2.683444 -0.421735      0.0  0.0

# %%
# Heatmap View
# 크게 Seasonality가 보이는 경향이 확실히 있음.
# 
plt.figure(figsize=(30, 7))
sns.heatmap(
    train[['Year', 'Day', 'Time', 'TARGET']]
    .groupby(["Day", "Time"]).TARGET.mean()
    .reset_index()
    .pivot("Time", "Day", "TARGET")
)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Time'>

# %%
def plotFeatureInDay(year, offset, size, features=["TARGET", "GHI"]):
    plt.figure(figsize=(15, 3))
    for day in range(offset, offset+size):
        # 'DHI', 'DNI', 'WS', 'RH', 'T'
        for feature in features:
            data = train.query(f"Year == {year}").query(f"Day == {day}")[["Time", feature]].reset_index(drop=True).set_index("Time")
            print("feature" + str(data.max().values))
            data = data / data.max()
            plt.plot(data, label=f"DAY {day} - " + feature)
    plt.legend()
    plt.show()

# %%
# DNI 가 더 stable한 변화를 보여줌. 안정적으로 예측하기 좋은 feature
# Elevation angle : https://www.pveducation.org/pvcdrom/properties-of-sunlight/elevation-angle
# sunrise 와 sunset 시간을 활용하여 TC(Time Correction)을 구하고,
# 이를 기반으로 HRA(Hour Angle)을 구하여, 현재 고도를 유추해볼 수 있음.
# 유추한 고도를 기반으로 DNI와 TARGET의 구체적인 관계식을 세워볼 수 있지 않을까 예상
plotFeatureInDay(1, 169, 1) # What a perfect day;
plotFeatureInDay(0, 3, 1)
plotFeatureInDay(1, 100, 1)
plotFeatureInDay(1, 30, 1)
# Out:
# feature[97.19007194]
# feature[1044.91535796]
# feature[38.00839039]
# feature[875.75156157]
# feature[72.34637608]
# feature[817.45816129]
# feature[33.87908378]
# feature[462.30599046]

# %%
# 외생변수를 제외하고는 GHI와 TARGET이 정비례한다는 가정
df = pd.DataFrame()
df["Year"] = train.Year
df["Day"] = train.Day
df["GHI"] = train.groupby(["Year", "Day"]).GHI.apply(lambda x: x / max(x))
df["TARGET"] = train.groupby(["Year", "Day"]).TARGET.apply(lambda x: x / max(x))
df["score"] = (df.GHI - df.TARGET) ** 2
top500_rmse = df.groupby(["Year", "Day"]).score.mean().pow(0.5).sort_values(ascending=True).head(500).reset_index()
display(top500_rmse)
# Out:
#      Year  Day     score
# 0       2  302  0.000007
# 1       2  129  0.000684
# 2       2  218  0.000746
# 3       0  155  0.000904
# 4       2  209  0.001086
# ..    ...  ...       ...
# 495     2   47  0.027956
# 496     1  251  0.027957
# 497     0   88  0.028380
# 498     1  111  0.028845
# 499     0   66  0.028881
#
# [500 rows x 3 columns]

# %%
ratios = (
    train
    .merge(top500_rmse, on=["Year", "Day"], how="inner")
    .assign(ratio=lambda df: df.TARGET / df.GHI)
    .dropna()
    .ratio
)

plt.figure(figsize=(15, 5))
n, b, patches = plt.hist(ratios, bins=150)
bin_max = np.where(n == n.max())
print(f"BIN MAX on : {b[bin_max][0]}")
plt.axvline(b[bin_max][0], color="r")
plt.title("TARGET/GHI ration on Top500 RMSE samples")
plt.show()
# Out:
# BIN MAX on : 0.09373626981869837

# %% [markdown]
# ## First attempt
# GHI와 비율을 활용하여 prediction 해보자

# %%
for test in tests:
    display(
        test.pipe(pipeTime)
    )
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-ea8cafc9e715> in <module>
#       1 for test in tests:
#       2     display(
# ----> 3         test.pipe(pipeTime)
#       4     )
#       5     break
#
# NameError: name 'pipeTime' is not defined
